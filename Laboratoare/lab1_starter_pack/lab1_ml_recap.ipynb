# %% [markdown]
# # Lab 1 — Recapitulare Machine Learning (Supervised & Unsupervised)
#
# Scopul acestui laborator este de a recapitula noțiunile fundamentale din *Machine Learning* înainte de a începe lucrul propriu-zis asupra primilor algoritmi de **Reinforcement Learning**.
# Vom lucra cu câteva seturi de date clasice din `scikit-learn` pentru a consolida înțelegerea procesului de învățare automată.
#
# ---
#
# ## 📘 Seturi de date folosite
#
# ### 🌸 Iris Dataset (Clasificare)
# - **Descriere:** unul dintre cele mai vechi seturi de date din ML, propus de Ronald Fisher (1936).
#   Conține 150 de flori din trei specii: *setosa*, *versicolor* și *virginica*, descrise prin 4 atribute numerice (lungime și lățime petală/sepală).
# - **Scop:** clasificarea tipului de floare pe baza acestor atribute.
# - **Link:** [Scikit-learn Iris Dataset](https://scikit-learn.org/stable/datasets/toy_dataset.html#iris-dataset)
#
# ---
#
# ### 🔢 Digits Dataset (Clasificare)
# - **Descriere:** imagini 8×8 pixeli cu cifre scrise de mână (0–9).
#   Fiecare imagine este reprezentată numeric, iar scopul este recunoașterea cifrei corecte.
# - **Scop:** antrenarea unui clasificator pentru recunoașterea cifrelor.
# - **Link:** [Scikit-learn Digits Dataset](https://scikit-learn.org/stable/datasets/toy_dataset.html#optical-recognition-of-handwritten-digits-dataset)
#
# ---
#
# ### 🏠 California Housing (Regresie)
# - **Descriere:** un set real (SUA - 1990), cu informații despre prețurile locuințelor din California.
#   Fiecare rând reprezintă o zonă, cu atribute precum densitate populației, venitul mediu, număr mediu de camere, etc.
# - **Scop:** estimarea valorii medii a unei locuințe / prețul unei locuințe.
# - **Link:** [Scikit-learn California Housing Dataset](https://scikit-learn.org/stable/datasets/real_world.html#california-housing-dataset)
#
# ---
#
# ### 🌀 Iris (K-Means + PCA)
# - **Descriere:** același set *Iris*, dar folosit în context nesupravegheat.
#   Vom aplica algoritmul **K-Means** pentru a descoperi grupările naturale și **PCA** pentru a reduce dimensiunea la 2D/3D.
# - **Scop:** demonstrarea relației între *dimensionality reduction* și *clustering*.
# - **Link:** [Scikit-learn PCA Documentation](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html)
#
# ---
#
# ## 🔍 Ce vom face
# 1. Clasificare: **KNN** și **Logistic Regression** (Iris)
# 2. Clasificare: **SVM** (Digits)
# 3. Regresie: **Random Forest** (California Housing)
# 4. Învățare nesupravegheată: **KMeans + PCA** (Iris)
#
# Fiecare secțiune include exerciții practice și **TODO-uri** care trebuie completate în timpul laboratorului.
#
# ---
#
# **Obiectiv general:** să recapitulăm fluxul complet al unui pipeline de inteligență artificială — de la citirea datelor până la evaluarea și interpretarea rezultatelor.
#
#
# ---
#
# # 📚 Librării folosite în acest laborator
#
# În acest laborator am lucrat cu cele mai utilizate librării din ecosistemul Python pentru Machine Learning.
#
# | Librărie | Rol / scop | Link documentație |
# |-----------|----------------|------------------|
# | **NumPy** | Calcul numeric, manipulare de vectori și matrici multidimensionale; baza pentru majoritatea librăriilor ML. | [https://numpy.org/doc/](https://numpy.org/doc/) |
# | **Pandas** | Manipulare de date în tabele (DataFrame-uri), similar cu Excel sau SQL. Ideal pentru preprocesare și analiză exploratorie. | [https://pandas.pydata.org/docs/](https://pandas.pydata.org/docs/) |
# | **Matplotlib** | Vizualizări 2D: grafice de acuratețe, dispersii, histograme, PCA etc. | [https://matplotlib.org/stable/contents.html](https://matplotlib.org/stable/contents.html) |
# | **Scikit-learn** | Toolkit complet pentru algoritmi de Machine Learning, evaluare, preprocesare, clustering, regresie etc. | [https://scikit-learn.org/stable/](https://scikit-learn.org/stable/) |
# | **Gymnasium** | Cadru pentru simularea mediilor de învățare prin interacțiune (RL). Oferă sute de medii standard precum CartPole, MountainCar, LunarLander etc. | [https://gymnasium.farama.org/](https://gymnasium.farama.org/) |
#
# ---
#
# ## 💡 Recomandare
# Incercați să urmați câteva tutoriale de bază pentru Python, în special aplicat în inteligența artificială:
# - [Awesome Machine Learning in Python](https://github.com/josephmisiti/awesome-machine-learning#python)
# - [Scikit-learn Tutorials](https://scikit-learn.org/1.4/tutorial/index.html)
# - [Gymnasium Examples](https://gymnasium.farama.org/introduction/basic_usage/)
#
# ---
#
# **Concluzie:**
# Aceste librării formează “trunchiul comun” al ecosistemului de învățare automată în Python.
# În următoarele laboratoare, vom extinde acest ecosistem cu librării dedicate *Reinforcement Learning*-ului (ex: `stable-baselines3`, `torch`, `rlberry`).

# %% [markdown]
# ## 1) Clasificare — Iris (KNN vs Logistic Regression)

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

data = load_iris()
x, y = data.data, data.target

# Pregătire date (split asupra setului de date + normalizare date - media datelor devine 0, iar deviația standard devine 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
sc = StandardScaler()
x_train_scaled = sc.fit_transform(x_train)
x_test_scaled = sc.transform(x_test)

# KNN
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train_scaled, y_train)
y_pred_knn = knn.predict(x_test_scaled)
print('KNN acc:', accuracy_score(y_test, y_pred_knn))

# Regresie logistică
lr = LogisticRegression(max_iter=1000)
lr.fit(x_train_scaled, y_train)
y_pred_lr = lr.predict(x_test_scaled)
print('LogReg acc:', accuracy_score(y_test, y_pred_lr))
print('\nReport (LR):\n', classification_report(y_test, y_pred_lr))

# %% [markdown]
# ### TODO 1
# - Ajustați hiperparametrii și încercați să reprezentați grafic acuratețea după acest pas. Exemplu: `n_neighbors` ∈ {1,3,5,7,9}.
# - Ce înseamnă precision, recall și f1-score?

# %%
import numpy as np, matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

results=[]; 
n_neighbors=[1, 3, 5, 7, 9]
# Puteti adauga mai multe variații ale hiperaparametrilor.

# Căutarea celui mai bun rezultat prin parcurgerea de mai jos se numește Grid Search.
for value in n_neighbors:
    m = KNeighborsClassifier(n_neighbors=value).fit(x_train_scaled, y_train)
    results.append(accuracy_score(y_test, m.predict(x_test_scaled)))

# Un plot simplu care să exemplifice acuratețea obținută în urma hiperparametrizării.
plt.figure()
plt.plot(n_neighbors, results, marker='o')
plt.title('n_neighbors grid search (Iris dataset)')
plt.xlabel('value')
plt.ylabel('accuracy')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2) Clasificare — Digits (SVM)

# %%
from sklearn.datasets import load_digits
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

digits = load_digits()
x, y = digits.data, digits.target

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

sc = StandardScaler()
x_train_scaled = sc.fit_transform(x_train)
x_test_scaled = sc.transform(x_test)

# SVC
svm = SVC(kernel='rbf', gamma='scale', C=3.0).fit(x_train_scaled, y_train)

print('SVM acc:', accuracy_score(y_test, svm.predict(x_test_scaled)))

# %% [markdown]
# ### TODO 2
# - Grid Search pe `C` ∈ {0.1, 1, 3, 10}; comentați rezultate (over/underfitting).
# - Incercați să rulați fără normalizare. Explorați diferența dintre un set de date prelucrat și unul fără prelucrări / raw.

# %% [markdown]
# ## 3) Regresie — California Housing (RandomForestRegressor)

# %% [markdown]
# ## 🏠 Vizualizare California Housing
#
# Setul de date *California Housing* conține informații reale despre locuințele din California (recensământul SUA din 1990).
# Fiecare eșantion reprezintă o regiune, descrisă prin variabile precum:
# - `MedInc` — venitul median al gospodăriei
# - `HouseAge` — vârsta mediană a clădirilor
# - `AveRooms` — numărul mediu de camere
# - `AveOccup` — numărul mediu de locuitori per gospodărie
# - `Latitude`, `Longitude` — coordonatele geografice
# - `MedHouseVal` — valoarea mediană a locuințelor (eticheta țintă, în sute de mii de dolari)
#
# Vom analiza relațiile de bază dintre variabile și distribuția geografică a prețurilor.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_california_housing

# Încărcăm dataset-ul sub formă de DataFrame (adică o matrice mai specială / tabel Excel)
cal = fetch_california_housing(as_frame=True)
df = cal.frame
df.head()

# %%
# DISTRIBUȚIA VALORILOR LOCUINȚELOR

plt.figure(figsize=(7,4))
sns.histplot(df["MedHouseVal"], bins=50, kde=True, color="steelblue")
plt.title("Distribuția valorii medii a locuințelor")
plt.xlabel("Valoare medie (sute de mii $)")
plt.ylabel("Frecvență")
plt.show()

# %%
# RELAȚIA DINTRE VENIT ȘI VALOAREA LOCUINȚEI

plt.figure(figsize=(6,5))
sns.scatterplot(x="MedInc", y="MedHouseVal", data=df, alpha=0.3)
plt.title("Relația dintre venitul mediu și valoarea locuinței")
plt.xlabel("Venit mediu (x10.000 $)")
plt.ylabel("Valoare medie (sute de mii $)")
plt.show()

# %%
# HARTĂ. FOLOSIȚI HARTA CALIFORNIEI ÎN LATERAL.

plt.figure(figsize=(8,6))
plt.scatter(
    df["Longitude"], df["Latitude"],
    c=df["MedHouseVal"], cmap="viridis",
    s=8, alpha=0.7
)
plt.colorbar(label="Valoare medie (sute de mii $)")
plt.title("Distribuția geografică a valorii locuințelor în California")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %%
# CORELAȚIE ÎNTRE VARIABILE

plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), cmap="coolwarm", annot=True, fmt=".2f")
plt.title("Matricea de corelație a caracteristicilor")
plt.show()

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score

x, y = fetch_california_housing(return_X_y=True)
# De ce random_state=42???
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Random Forest
# Iar 42? Număr magic?
rf = RandomForestRegressor(n_estimators=200, random_state=42, n_jobs=-1).fit(x_train, y_train)
pred = rf.predict(x_test)

# Ce inseamna mean absolute error / R2 score?
print('MAE:', mean_absolute_error(y_test, pred))
print('R2:', r2_score(y_test, pred))

# %% [markdown]
# ### TODO 3
# - Comparați cu `LinearRegression` + standardizare.
# - Ce alte explorări de date propuneți?

# %% [markdown]
# ## 4) Unsupervised — KMeans + PCA (Iris)

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt, numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import adjusted_rand_score

x = data.data
x_scaled = StandardScaler().fit_transform(x)

# KMeans - clustering
km = KMeans(n_clusters=3, n_init=10, random_state=42).fit(x_scaled)
labels = km.labels_

# PCA - reduce numărul de componente
pca = PCA(n_components=2, random_state=42)
x_2pca = pca.fit_transform(x_scaled)

plt.figure()
plt.scatter(x_2pca[:, 0], x_2pca[:, 1], c=labels, s=40)
plt.title('KMeans clusters (PCA 2D)')
plt.show()

# Ce ar însemna ARI vs. true labels? Google it! Să aflăm împreună!
print('ARI vs. true labels:', adjusted_rand_score(data.target, labels))

# %% [markdown]
# ### TODO 4
# Incercați PCA 3D și comparați colorarea după `labels` vs. `y`.
